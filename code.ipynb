# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # import linear

# %%
df1=pd.read_csv("linear_data.csv")

# %%
df1
# Out:
#      x    y
# 0    0    7
# 1    1   10
# 2    2   13
# 3    3   16
# 4    4   19
# ..  ..  ...
# 95  95  292
# 96  96  295
# 97  97  298
# 98  98  301
# 99  99  304
#
# [100 rows x 2 columns]

# %%
x_linear=df1[['x']]
y_linear=df1[['y']]

# %% [markdown]
# # import non linear

# %%
df2=pd.read_csv("non_linear_data1.csv")

# %%
df2
# Out:
#             x         y        X3  label
# 0   -0.926767 -0.111073  0.086017      0
# 1   -0.917583  0.706006  0.058041      0
# 2    0.437984  0.899093  0.072543      0
# 3    0.089694  0.291446  0.070444      1
# 4    0.110672 -0.070806 -0.090376      1
# ..        ...       ...       ...    ...
# 195 -0.540630  0.901834 -0.058539      0
# 196  0.032085  0.411465 -0.064823      1
# 197  0.691922  0.679103  0.020613      0
# 198  0.017034  0.930984 -0.034133      0
# 199  0.212676 -0.026037  0.013321      1
#
# [200 rows x 4 columns]

# %%
x_non_linear=df2[['x']]
y_non_linear=df2[['y']]

# %% [markdown]
# # Visual representation

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(x_linear,y_linear,color='blue',label='Data with Linear linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("linear relationship")
plt.legend()

#non linear
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
plt.scatter(x_non_linear,y_non_linear,color='green',label='Data with non Linear linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("non linear relationship")
plt.legend()

plt.tight_layout()
plt.show()

# %%
df1.corr()
# Out:
#      x    y
# x  1.0  1.0
# y  1.0  1.0

# %%
df2.corr()
# Out:
#               x         y        X3     label
# x      1.000000 -0.421781  0.052467  0.567705
# y     -0.421781  1.000000  0.130257 -0.751046
# X3     0.052467  0.130257  1.000000 -0.043088
# label  0.567705 -0.751046 -0.043088  1.000000

# %% [markdown]
# # Linear

# %%
from sklearn.linear_model import LinearRegression

# %%
reg1=LinearRegression()

# %%
reg1.fit(x_linear,y_linear)
# Out:
# LinearRegression()

# %%
reg1.score(x_linear,y_linear)
# Out:
# 1.0

# %%
plt.scatter(x_linear,y_linear,color='blue',label='Data with Linear linear Relationship')
plt.plot(x_linear,reg1.predict(x_linear),color='red',label='best fit line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("linear relationship")
plt.legend()
plt.show()

# %% [markdown]
# # NOn linear

# %%
reg2=LinearRegression()

# %%
reg1.fit(x_linear,y_linear)
# Out:
# LinearRegression()

# %%
reg1.score(x_non_linear,y_non_linear)
# Out:
# -298.3932900343908

# %%
plt.scatter(x_non_linear,y_non_linear,color='Green',label='Data with Linear linear Relationship')
plt.plot(x_non_linear,reg1.predict(x_non_linear),color='red',label='best fit line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("non linear relationship")
plt.legend()
plt.show()

# %% [markdown]
# # polynomial regreession

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=20)
X_poly=poly.fit_transform(x_non_linear)

# %%
X_poly.shape
# Out:
# (200, 21)

# %%
reg_poly=LinearRegression()

# %%
reg_poly.fit(X_poly,y_non_linear)
# Out:
# LinearRegression()

# %%
reg_poly.score(X_poly,y_non_linear)
# Out:
# 0.4145625939052019

# %%
plt.scatter(x_non_linear,y_non_linear,color='Green',label='Data with Linear linear Relationship')
plt.plot(x_non_linear,reg1.predict(x_non_linear),color='orange',label='True non linear relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("non linear relationship")
plt.legend()
plt.show()

# %% [markdown]
# # separate train test

# %%
from sklearn.model_selection import train_test_split

# Correct call
xtrain, xtest, ytrain, ytest = train_test_split(X_poly, y_non_linear, test_size=0.3, random_state=1)

# %%
reg=LinearRegression()

# %%
 reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# # testing Score

# %%
reg.score(xtest,ytest)
# Out:
# 0.1514264128219318

# %% [markdown]
# # Traning score

# %%
reg.score(xtrain,ytrain)
# Out:
# 0.44996743704767717
